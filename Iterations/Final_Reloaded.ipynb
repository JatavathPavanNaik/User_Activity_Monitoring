# %%
import cv2
from ultralytics import YOLO
import random
import pandas as pd


# Initialize the YOLO model
model = YOLO("/Users/jatavathpavannaik/Documents/python/Computer_Vision/YOLOV8/runs/detect/train_cpu/weights/best.pt")

# Open video capture
cap = cv2.VideoCapture('/Users/jatavathpavannaik/Documents/python/Computer_Vision/test_case_03.mov')  # Replace 'path_to_video.mp4' with your video file
  # Replace 'path_to_video.mp4' with your video file
fps = cap.get(cv2.CAP_PROP_FPS)
# Create a list to store areas of bounding boxes for each frame
all_areas = []

frame_number = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    frame_number += 1
    
    # Make predictions
    results = model.predict(frame)
    
    # Extract bounding box information
    boxes = results[0].boxes.xyxy.tolist()
    classes = results[0].boxes.cls.tolist()
    names = results[0].names
    confidences = results[0].boxes.conf.tolist()
    
    # Draw bounding boxes on the frame and calculate areas
    areas=[]
    for box, cls, conf in zip(boxes, classes, confidences):
        x1, y1, x2, y2 = box
        class_name = names[int(cls)]
        color = (0, 255, 0)  # Green color for bounding box
        cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
        cv2.putText(frame, f'{class_name} {conf:.2f}', (int(x1), int(y1 - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        
        # Calculate area
        area = (x2 - x1) * (y2 - y1)
        areas.append(area)
    
    # Store areas of bounding boxes for this frame
    all_areas.append((frame_number, areas))
    
    # Display the frame with bounding boxes
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 51.1ms
# Speed: 5.2ms preprocess, 51.1ms inference, 10.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 73.1ms
# Speed: 1.0ms preprocess, 73.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 33.4ms
# Speed: 0.7ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 27.7ms
# Speed: 0.8ms preprocess, 27.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 28.3ms
# Speed: 0.6ms preprocess, 28.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 29.0ms
# Speed: 0.7ms preprocess, 29.0ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 30.9ms
# Speed: 1.0ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 28.3ms
# Speed: 0.9ms preprocess, 28.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 card, 26.0ms
# Speed: 0.8ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 card, 27.1ms
# Speed: 0.8ms preprocess, 27.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 26.7ms
# Speed: 0.9ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 25.6ms
# Speed: 1.2ms preprocess, 25.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 27.0ms
# Speed: 0.7ms preprocess, 27.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 25.8ms
# Speed: 0.8ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 28.1ms
# Speed: 0.6ms preprocess, 28.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 26.6ms
# Speed: 0.7ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 27.3ms
# Speed: 0.7ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 29.6ms
# Speed: 0.7ms preprocess, 29.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 27.5ms
# Speed: 0.6ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 28.4ms
# Speed: 0.8ms preprocess, 28.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 28.1ms
# Speed: 0.7ms preprocess, 28.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 card, 1 pop-up, 28.5ms
# Speed: 0.7ms preprocess, 28.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 27.8ms
# Speed: 0.7ms preprocess, 27.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 30.1ms
# Speed: 0.6ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 24.2ms
# Speed: 0.8ms preprocess, 24.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 27.0ms
# Speed: 0.7ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 24.0ms
# Speed: 0.9ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 25.5ms
# Speed: 0.9ms preprocess, 25.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 26.1ms
# Speed: 0.6ms preprocess, 26.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 pop-up, 27.5ms
# Speed: 0.9ms preprocess, 27.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 footer, 1 pop-up, 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 card, 1 pop-up, 25.9ms
# Speed: 0.8ms preprocess, 25.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 26.5ms
# Speed: 0.9ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 pop-up, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 image, 1 pop-up, 1 title, 25.1ms
# Speed: 0.8ms preprocess, 25.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 1 title, 29.1ms
# Speed: 0.7ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 26.8ms
# Speed: 0.7ms preprocess, 26.8ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 1 title, 29.8ms
# Speed: 0.9ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 image, 1 pop-up, 28.4ms
# Speed: 0.7ms preprocess, 28.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 image, 1 pop-up, 1 title, 30.1ms
# Speed: 0.7ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 image, 1 pop-up, 28.9ms
# Speed: 0.7ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 image, 1 pop-up, 28.8ms
# Speed: 0.7ms preprocess, 28.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 1 image, 1 pop-up, 29.4ms
# Speed: 0.8ms preprocess, 29.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 heading, 1 pop-up, 27.5ms
# Speed: 0.7ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 1 pop-up, 2 titles, 28.1ms
# Speed: 0.8ms preprocess, 28.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 pop-up, 1 title, 27.4ms
# Speed: 0.6ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 28.8ms
# Speed: 1.0ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 alert, 1 pop-up, 1 title, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 alert, 1 heading, 1 pop-up, 1 title, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 pop-up, 1 title, 27.1ms
# Speed: 0.7ms preprocess, 27.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 pop-up, 1 title, 26.1ms
# Speed: 0.9ms preprocess, 26.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 pop-up, 1 title, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 heading, 1 image, 1 pop-up, 2 titles, 27.5ms
# Speed: 0.7ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 1 pop-up, 1 title, 25.2ms
# Speed: 0.9ms preprocess, 25.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 25.9ms
# Speed: 0.7ms preprocess, 25.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 heading, 1 image, 1 pop-up, 25.9ms
# Speed: 0.7ms preprocess, 25.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 badge, 1 heading, 1 pop-up, 26.6ms
# Speed: 0.6ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 badge, 1 heading, 1 pop-up, 25.6ms
# Speed: 0.9ms preprocess, 25.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 badge, 1 image, 1 pop-up, 33.8ms
# Speed: 0.8ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 1 image, 1 pop-up, 27.0ms
# Speed: 0.7ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 1 pop-up, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 1 pop-up, 2 titles, 25.4ms
# Speed: 0.9ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 navigation, 1 pop-up, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 badge, 1 card, 1 pop-up, 23.8ms
# Speed: 0.8ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 navigation, 30.8ms
# Speed: 0.6ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 navigation, 23.8ms
# Speed: 0.8ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 header, 1 image, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 image, 1 pop-up, 27.5ms
# Speed: 0.8ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 header, 1 heading, 1 image, 1 pop-up, 26.7ms
# Speed: 0.7ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 header, 1 heading, 1 image, 1 pop-up, 62.7ms
# Speed: 0.8ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 Input field, 1 ad, 1 alert, 1 badge, 1 header, 1 heading, 1 image, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 badge, 1 heading, 1 image, 26.4ms
# Speed: 0.7ms preprocess, 26.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 badge, 1 heading, 2 images, 26.4ms
# Speed: 0.7ms preprocess, 26.4ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 badge, 1 heading, 2 images, 26.3ms
# Speed: 0.5ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 badge, 1 heading, 2 images, 26.2ms
# Speed: 0.7ms preprocess, 26.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 badge, 1 heading, 2 images, 26.4ms
# Speed: 0.8ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 badge, 1 heading, 2 images, 30.9ms
# Speed: 0.6ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 badge, 1 heading, 2 images, 1 pop-up, 30.4ms
# Speed: 0.5ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 badge, 1 card, 2 images, 1 pop-up, 30.6ms
# Speed: 0.7ms preprocess, 30.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 header, 1 heading, 2 images, 2 pop-ups, 33.7ms
# Speed: 0.6ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 3 CTAs, 1 ad, 2 images, 1 pop-up, 26.0ms
# Speed: 0.9ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 3 images, 1 pop-up, 28.0ms
# Speed: 0.7ms preprocess, 28.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 2 headers, 2 images, 1 pagination, 2 pop-ups, 1 title, 27.4ms
# Speed: 0.8ms preprocess, 27.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 2 images, 1 pop-up, 26.9ms
# Speed: 0.6ms preprocess, 26.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 copy, 2 images, 1 pop-up, 28.4ms
# Speed: 0.6ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 alert, 1 copy, 2 images, 1 pop-up, 23.9ms
# Speed: 0.8ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 2 images, 1 pop-up, 26.8ms
# Speed: 0.9ms preprocess, 26.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 3 images, 1 pop-up, 26.8ms
# Speed: 0.7ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 2 images, 1 pop-up, 26.8ms
# Speed: 1.0ms preprocess, 26.8ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 heading, 3 images, 1 pop-up, 24.8ms
# Speed: 0.7ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 3 images, 1 pop-up, 28.2ms
# Speed: 0.9ms preprocess, 28.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 3 images, 1 navigation, 1 pop-up, 29.3ms
# Speed: 0.8ms preprocess, 29.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 3 images, 1 pop-up, 32.3ms
# Speed: 0.8ms preprocess, 32.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 2 images, 1 pop-up, 29.7ms
# Speed: 0.9ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 headings, 2 images, 1 pop-up, 30.0ms
# Speed: 0.8ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 28.0ms
# Speed: 0.7ms preprocess, 28.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 25.8ms
# Speed: 1.4ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 26.2ms
# Speed: 0.7ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 29.8ms
# Speed: 1.2ms preprocess, 29.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 1 pop-up, 29.0ms
# Speed: 0.8ms preprocess, 29.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 heading, 3 images, 26.7ms
# Speed: 0.8ms preprocess, 26.7ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 3 images, 27.7ms
# Speed: 0.7ms preprocess, 27.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 heading, 3 images, 26.0ms
# Speed: 0.7ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 24.0ms
# Speed: 0.9ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 27.7ms
# Speed: 0.7ms preprocess, 27.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 3 images, 30.0ms
# Speed: 0.7ms preprocess, 30.0ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 27.1ms
# Speed: 0.8ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 30.2ms
# Speed: 0.8ms preprocess, 30.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 25.1ms
# Speed: 0.9ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 29.2ms
# Speed: 0.8ms preprocess, 29.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 28.1ms
# Speed: 0.8ms preprocess, 28.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 28.7ms
# Speed: 0.7ms preprocess, 28.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 25.7ms
# Speed: 1.2ms preprocess, 25.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 5 ads, 1 copy, 1 heading, 4 images, 25.6ms
# Speed: 0.8ms preprocess, 25.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 5 ads, 1 copy, 1 heading, 4 images, 24.5ms
# Speed: 0.6ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 5 ads, 1 copy, 1 heading, 4 images, 30.4ms
# Speed: 0.7ms preprocess, 30.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 5 ads, 1 copy, 1 heading, 4 images, 26.3ms
# Speed: 0.6ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 26.6ms
# Speed: 0.7ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 27.5ms
# Speed: 0.8ms preprocess, 27.5ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 26.0ms
# Speed: 0.7ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 27.1ms
# Speed: 0.8ms preprocess, 27.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 26.4ms
# Speed: 0.9ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 42.9ms
# Speed: 0.7ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 28.9ms
# Speed: 0.8ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 28.7ms
# Speed: 0.6ms preprocess, 28.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 27.7ms
# Speed: 0.6ms preprocess, 27.7ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 42.4ms
# Speed: 0.7ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 26.3ms
# Speed: 0.7ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 68.1ms
# Speed: 0.8ms preprocess, 68.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 31.2ms
# Speed: 0.7ms preprocess, 31.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 24.7ms
# Speed: 0.8ms preprocess, 24.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 32.6ms
# Speed: 0.8ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 4 ads, 1 copy, 1 heading, 4 images, 28.6ms
# Speed: 0.8ms preprocess, 28.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 3 ads, 1 copy, 1 heading, 4 images, 29.9ms
# Speed: 0.9ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 30.4ms
# Speed: 0.9ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 5 images, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 5 images, 1 navigation, 25.6ms
# Speed: 0.9ms preprocess, 25.6ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 32.0ms
# Speed: 0.8ms preprocess, 32.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 29.6ms
# Speed: 0.8ms preprocess, 29.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 33.1ms
# Speed: 0.8ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 28.7ms
# Speed: 0.8ms preprocess, 28.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 31.2ms
# Speed: 0.8ms preprocess, 31.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 27.3ms
# Speed: 0.8ms preprocess, 27.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 30.5ms
# Speed: 0.7ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 24.2ms
# Speed: 0.9ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 28.9ms
# Speed: 0.9ms preprocess, 28.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 27.8ms
# Speed: 0.8ms preprocess, 27.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 28.7ms
# Speed: 1.0ms preprocess, 28.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 26.8ms
# Speed: 0.7ms preprocess, 26.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 27.6ms
# Speed: 0.7ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 26.8ms
# Speed: 0.9ms preprocess, 26.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 copy, 1 heading, 4 images, 30.3ms
# Speed: 0.7ms preprocess, 30.3ms inference, 0.7ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 2 ads, 1 copy, 1 heading, 4 images, 27.6ms
# Speed: 0.9ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 2 ads, 1 heading, 2 images, 1 pop-up, 31.8ms
# Speed: 0.6ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 header, 1 heading, 3 images, 1 pop-up, 27.7ms
# Speed: 0.8ms preprocess, 27.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 ads, 1 header, 1 heading, 4 images, 1 pop-up, 25.6ms
# Speed: 0.7ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 3 images, 1 pop-up, 27.4ms
# Speed: 0.8ms preprocess, 27.4ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 heading, 5 images, 1 pop-up, 29.0ms
# Speed: 0.7ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 4 images, 1 pop-up, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 1 hero image, 5 images, 1 navigation, 31.3ms
# Speed: 0.9ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 headings, 1 hero image, 5 images, 25.6ms
# Speed: 0.8ms preprocess, 25.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 1 hero image, 5 images, 28.2ms
# Speed: 0.8ms preprocess, 28.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 headings, 1 hero image, 4 images, 29.4ms
# Speed: 0.8ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 headings, 1 hero image, 7 images, 30.7ms
# Speed: 0.9ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 1 hero image, 6 images, 26.0ms
# Speed: 1.2ms preprocess, 26.0ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 5 images, 31.9ms
# Speed: 1.3ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 headings, 1 hero image, 5 images, 1 tag, 33.8ms
# Speed: 0.8ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 headings, 1 hero image, 5 images, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 1 hero image, 5 images, 41.8ms
# Speed: 0.7ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 31.3ms
# Speed: 1.0ms preprocess, 31.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 28.9ms
# Speed: 0.7ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 26.1ms
# Speed: 0.7ms preprocess, 26.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 27.1ms
# Speed: 0.7ms preprocess, 27.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 25.5ms
# Speed: 0.9ms preprocess, 25.5ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 28.6ms
# Speed: 0.7ms preprocess, 28.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 hero image, 4 images, 28.8ms
# Speed: 0.8ms preprocess, 28.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 hero image, 4 images, 28.2ms
# Speed: 0.7ms preprocess, 28.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 hero image, 4 images, 34.8ms
# Speed: 5.8ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 hero image, 4 images, 25.9ms
# Speed: 0.7ms preprocess, 25.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 29.0ms
# Speed: 0.8ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 25.3ms
# Speed: 0.7ms preprocess, 25.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 header, 1 hero image, 4 images, 24.5ms
# Speed: 0.9ms preprocess, 24.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 hero image, 4 images, 30.1ms
# Speed: 0.7ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 2 headings, 1 hero image, 6 images, 27.7ms
# Speed: 1.0ms preprocess, 27.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 headings, 1 hero image, 5 images, 28.5ms
# Speed: 0.8ms preprocess, 28.5ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 2 ads, 2 headings, 1 hero image, 4 images, 27.3ms
# Speed: 0.9ms preprocess, 27.3ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 2 headings, 1 hero image, 1 image, 1 navigation, 28.1ms
# Speed: 0.8ms preprocess, 28.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 headings, 8 images, 29.2ms
# Speed: 0.7ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 3 ads, 2 headings, 3 images, 31.2ms
# Speed: 0.8ms preprocess, 31.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 6 images, 27.3ms
# Speed: 0.8ms preprocess, 27.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 2 images, 1 title, 30.5ms
# Speed: 0.9ms preprocess, 30.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 3 images, 27.2ms
# Speed: 0.8ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 card, 2 images, 1 title, 29.6ms
# Speed: 0.9ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 2 headings, 2 images, 29.3ms
# Speed: 0.7ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 1 heading, 3 images, 36.5ms
# Speed: 0.8ms preprocess, 36.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 1 heading, 5 images, 26.2ms
# Speed: 0.9ms preprocess, 26.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 3 cards, 1 heading, 7 images, 32.1ms
# Speed: 0.8ms preprocess, 32.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 1 heading, 7 images, 1 title, 28.2ms
# Speed: 0.8ms preprocess, 28.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 7 images, 1 title, 26.3ms
# Speed: 0.7ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 6 images, 1 title, 27.8ms
# Speed: 0.7ms preprocess, 27.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 5 images, 29.0ms
# Speed: 0.7ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 5 cards, 1 heading, 4 images, 1 title, 25.9ms
# Speed: 0.8ms preprocess, 25.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 card, 1 heading, 5 images, 30.6ms
# Speed: 0.7ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 2 cards, 1 header, 1 heading, 5 images, 30.3ms
# Speed: 0.6ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 2 headings, 5 images, 28.4ms
# Speed: 1.2ms preprocess, 28.4ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 1 heading, 6 images, 27.7ms
# Speed: 1.1ms preprocess, 27.7ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 6 images, 30.6ms
# Speed: 0.7ms preprocess, 30.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 6 images, 27.6ms
# Speed: 0.7ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 6 images, 26.7ms
# Speed: 0.9ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 6 images, 29.9ms
# Speed: 0.6ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 heading, 6 images, 25.3ms
# Speed: 0.7ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 3 images, 29.0ms
# Speed: 0.9ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 heading, 4 images, 1 navigation, 29.4ms
# Speed: 0.7ms preprocess, 29.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 3 images, 26.3ms
# Speed: 0.8ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 6 cards, 1 heading, 4 images, 1 pop-up, 1 title, 28.6ms
# Speed: 0.7ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 4 images, 1 pop-up, 30.8ms
# Speed: 1.2ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 cards, 1 heading, 3 images, 1 pop-up, 91.8ms
# Speed: 1.0ms preprocess, 91.8ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 3 images, 27.0ms
# Speed: 0.8ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 3 images, 32.4ms
# Speed: 0.9ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 4 images, 36.0ms
# Speed: 0.7ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 4 images, 31.2ms
# Speed: 0.8ms preprocess, 31.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 5 images, 28.1ms
# Speed: 0.9ms preprocess, 28.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 6 images, 37.6ms
# Speed: 0.9ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 6 images, 34.6ms
# Speed: 0.7ms preprocess, 34.6ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 heading, 5 images, 26.3ms
# Speed: 0.8ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 heading, 5 images, 27.3ms
# Speed: 0.7ms preprocess, 27.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 4 images, 71.6ms
# Speed: 0.7ms preprocess, 71.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 4 images, 26.7ms
# Speed: 0.9ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 4 images, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 3 images, 28.8ms
# Speed: 0.6ms preprocess, 28.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 3 images, 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 6 images, 27.8ms
# Speed: 0.9ms preprocess, 27.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 5 images, 31.1ms
# Speed: 0.9ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 3 images, 27.8ms
# Speed: 0.8ms preprocess, 27.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 badge, 1 card, 4 images, 26.2ms
# Speed: 1.1ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 card, 3 images, 28.6ms
# Speed: 1.2ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 card, 3 images, 26.3ms
# Speed: 0.7ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 card, 3 images, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 card, 4 images, 29.1ms
# Speed: 0.6ms preprocess, 29.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 5 images, 30.9ms
# Speed: 0.8ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 card, 1 heading, 3 images, 27.6ms
# Speed: 0.8ms preprocess, 27.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 4 cards, 2 images, 27.4ms
# Speed: 0.6ms preprocess, 27.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 images, 1 pop-up, 26.2ms
# Speed: 0.8ms preprocess, 26.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 ads, 1 card, 1 heading, 2 images, 1 pop-up, 28.1ms
# Speed: 0.8ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 image, 1 pop-up, 31.0ms
# Speed: 0.7ms preprocess, 31.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 3 images, 28.4ms
# Speed: 0.9ms preprocess, 28.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 2 images, 28.5ms
# Speed: 1.1ms preprocess, 28.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 images, 34.0ms
# Speed: 0.7ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 images, 1 title, 1 tooltip, 30.2ms
# Speed: 0.7ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 pop-up, 27.8ms
# Speed: 0.7ms preprocess, 27.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 title, 32.1ms
# Speed: 0.8ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 image, 27.7ms
# Speed: 0.9ms preprocess, 27.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 image, 27.0ms
# Speed: 0.8ms preprocess, 27.0ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 1 title, 28.3ms
# Speed: 0.8ms preprocess, 28.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 28.2ms
# Speed: 0.8ms preprocess, 28.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 27.4ms
# Speed: 0.9ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 heading, 29.8ms
# Speed: 0.7ms preprocess, 29.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 25.4ms
# Speed: 0.8ms preprocess, 25.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 31.0ms
# Speed: 0.8ms preprocess, 31.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 30.8ms
# Speed: 0.8ms preprocess, 30.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 header, 25.9ms
# Speed: 0.8ms preprocess, 25.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 header, 1 hero image, 26.2ms
# Speed: 0.7ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 28.5ms
# Speed: 0.7ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 24.7ms
# Speed: 0.7ms preprocess, 24.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 30.7ms
# Speed: 0.7ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 31.7ms
# Speed: 0.8ms preprocess, 31.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 26.5ms
# Speed: 0.6ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 27.9ms
# Speed: 0.9ms preprocess, 27.9ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 card, 1 hero image, 26.1ms
# Speed: 0.6ms preprocess, 26.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 hero image, 1 pop-up, 1 title, 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 hero image, 1 illustration, 1 title, 27.9ms
# Speed: 0.8ms preprocess, 27.9ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 hero image, 1 image, 2 titles, 36.7ms
# Speed: 10.9ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 header, 1 heading, 1 hero image, 1 image, 1 title, 30.0ms
# Speed: 0.5ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 hero image, 2 titles, 28.7ms
# Speed: 0.8ms preprocess, 28.7ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 1 hero image, 1 image, 2 titles, 25.6ms
# Speed: 0.7ms preprocess, 25.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 hero image, 1 image, 1 title, 33.6ms
# Speed: 0.7ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 1 image, 1 title, 30.6ms
# Speed: 0.8ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 heading, 1 hero image, 1 image, 3 titles, 29.9ms
# Speed: 0.9ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 1 image, 1 pop-up, 2 titles, 25.2ms
# Speed: 0.7ms preprocess, 25.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 1 image, 1 pop-up, 1 title, 36.0ms
# Speed: 0.8ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 1 image, 1 pop-up, 2 titles, 26.5ms
# Speed: 0.9ms preprocess, 26.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 1 pop-up, 1 title, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 hero image, 1 pop-up, 30.0ms
# Speed: 0.7ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 heading, 1 hero image, 1 image, 1 navigation, 1 pop-up, 1 title, 33.0ms
# Speed: 0.8ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 1 image, 1 pop-up, 2 titles, 27.5ms
# Speed: 0.7ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 hero image, 1 image, 1 pop-up, 1 title, 27.6ms
# Speed: 0.9ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 1 hero image, 1 image, 1 pop-up, 3 titles, 29.0ms
# Speed: 0.9ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 1 badge, 1 hero image, 1 pop-up, 2 titles, 29.9ms
# Speed: 0.9ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 3 CTAs, 2 ads, 1 hero image, 1 pop-up, 3 titles, 28.8ms
# Speed: 0.9ms preprocess, 28.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 hero image, 1 pop-up, 1 title, 31.1ms
# Speed: 0.8ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 alert, 1 hero image, 1 title, 28.6ms
# Speed: 0.7ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 3 titles, 27.1ms
# Speed: 0.9ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 3 titles, 26.0ms
# Speed: 0.7ms preprocess, 26.0ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 hero image, 3 titles, 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 heading, 1 hero image, 2 titles, 27.1ms
# Speed: 0.7ms preprocess, 27.1ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 heading, 1 hero image, 2 titles, 28.3ms
# Speed: 0.8ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 heading, 1 hero image, 25.0ms
# Speed: 0.8ms preprocess, 25.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 header, 1 hero image, 2 titles, 24.9ms
# Speed: 0.9ms preprocess, 24.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 alert, 1 heading, 1 hero image, 31.2ms
# Speed: 0.6ms preprocess, 31.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 alert, 2 hero images, 1 illustration, 1 pop-up, 26.5ms
# Speed: 0.9ms preprocess, 26.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# ...
#
# 0: 160x224 1 ad, 1 pop-up, 38.0ms
# Speed: 0.8ms preprocess, 38.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 navigation, 1 pop-up, 27.3ms
# Speed: 0.7ms preprocess, 27.3ms inference, 0.7ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 pop-up, 27.1ms
# Speed: 0.6ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 pop-up, 1 title, 26.9ms
# Speed: 0.7ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 1 title, 32.9ms
# Speed: 3.7ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 37.2ms
# Speed: 0.8ms preprocess, 37.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 dropdown, 1 pop-up, 25.4ms
# Speed: 0.8ms preprocess, 25.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 1 footer, 1 pop-up, 29.3ms
# Speed: 0.9ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 2 alerts, 1 footer, 28.6ms
# Speed: 0.9ms preprocess, 28.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 2 alerts, 1 footer, 27.5ms
# Speed: 0.6ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 2 alerts, 1 footer, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 alerts, 1 footer, 1 header, 28.2ms
# Speed: 0.7ms preprocess, 28.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 2 alerts, 1 card, 1 dropdown, 1 footer, 1 header, 26.6ms
# Speed: 0.8ms preprocess, 26.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 alerts, 1 footer, 1 header, 33.3ms
# Speed: 0.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 2 alerts, 2 footers, 2 headers, 1 tab, 35.3ms
# Speed: 0.9ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 2 alerts, 1 footer, 1 header, 1 tab, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 3 alerts, 1 dropdown, 2 footers, 2 headers, 1 tab, 25.4ms
# Speed: 0.7ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 3 alerts, 1 dropdown, 2 footers, 2 headers, 1 tab, 26.9ms
# Speed: 0.9ms preprocess, 26.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 2 alerts, 1 footer, 1 header, 1 tab, 28.8ms
# Speed: 0.8ms preprocess, 28.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 2 alerts, 1 dropdown, 1 footer, 1 header, 1 tab, 26.9ms
# Speed: 0.8ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 Input field, 1 ad, 3 alerts, 1 footer, 1 header, 1 tab, 37.7ms
# Speed: 0.7ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 3 alerts, 1 footer, 2 headers, 26.2ms
# Speed: 0.8ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 3 alerts, 2 footers, 1 header, 25.2ms
# Speed: 0.7ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 3 alerts, 1 footer, 1 header, 26.9ms
# Speed: 0.8ms preprocess, 26.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 alerts, 1 footer, 1 header, 28.5ms
# Speed: 0.7ms preprocess, 28.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 alerts, 1 footer, 1 header, 43.2ms
# Speed: 0.7ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 3 alerts, 1 footer, 1 header, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 alerts, 1 footer, 2 headers, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 2 alerts, 1 footer, 1 header, 24.5ms
# Speed: 0.7ms preprocess, 24.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 2 alerts, 1 footer, 1 header, 27.4ms
# Speed: 0.8ms preprocess, 27.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 Input field, 1 ad, 2 alerts, 1 footer, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.4ms
# Speed: 0.8ms preprocess, 27.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 Input fields, 1 ad, 1 pop-up, 25.8ms
# Speed: 0.7ms preprocess, 25.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 footer, 1 navigation, 1 pop-up, 28.3ms
# Speed: 0.8ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 footer, 1 pop-up, 27.2ms
# Speed: 0.9ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 2 Input fields, 1 ad, 1 pop-up, 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 header, 26.4ms
# Speed: 0.7ms preprocess, 26.4ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 29.3ms
# Speed: 1.7ms preprocess, 29.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 ad, 1 data feed, 26.0ms
# Speed: 0.9ms preprocess, 26.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 33.0ms
# Speed: 7.7ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 Input field, 1 ad, 1 navigation, 35.5ms
# Speed: 0.8ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 Input field, 1 ad, 1 header, 26.3ms
# Speed: 0.9ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 Input field, 1 ad, 1 header, 1 logo, 24.2ms
# Speed: 0.8ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 footer, 28.9ms
# Speed: 0.7ms preprocess, 28.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 footer, 1 pop-up, 26.5ms
# Speed: 0.8ms preprocess, 26.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 alert, 1 footer, 1 pop-up, 37.0ms
# Speed: 0.6ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 footer, 1 pop-up, 26.7ms
# Speed: 0.8ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 footer, 1 pop-up, 27.5ms
# Speed: 0.9ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 footer, 1 pop-up, 33.9ms
# Speed: 6.4ms preprocess, 33.9ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 footer, 1 pop-up, 26.5ms
# Speed: 0.9ms preprocess, 26.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 Input field, 1 pop-up, 25.7ms
# Speed: 0.8ms preprocess, 25.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 ad, 1 footer, 1 navigation, 1 pop-up, 27.6ms
# Speed: 0.9ms preprocess, 27.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 navigation, 1 pop-up, 26.0ms
# Speed: 0.6ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 Input field, 1 ad, 1 pop-up, 26.5ms
# Speed: 0.7ms preprocess, 26.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 Input fields, 1 ad, 1 pop-up, 28.3ms
# Speed: 0.7ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 ad, 1 pop-up, 37.4ms
# Speed: 0.5ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 pop-up, 26.1ms
# Speed: 0.7ms preprocess, 26.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 Input field, 1 alert, 1 pop-up, 52.3ms
# Speed: 1.3ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 pop-up, 1 title, 25.2ms
# Speed: 0.8ms preprocess, 25.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 pop-up, 1 title, 37.4ms
# Speed: 0.8ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 1 CTA, 1 pop-up, 24.6ms
# Speed: 0.8ms preprocess, 24.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 ad, 1 alert, 1 pop-up, 27.9ms
# Speed: 0.8ms preprocess, 27.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.0ms
# Speed: 0.8ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 alert, 1 pop-up, 27.4ms
# Speed: 0.8ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 alert, 1 pop-up, 26.3ms
# Speed: 0.7ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.3ms
# Speed: 0.7ms preprocess, 27.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 34.9ms
# Speed: 2.7ms preprocess, 34.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.5ms
# Speed: 0.7ms preprocess, 26.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.2ms
# Speed: 0.7ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 23.8ms
# Speed: 0.6ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.6ms
# Speed: 0.7ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 24.4ms
# Speed: 0.8ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.7ms
# Speed: 0.6ms preprocess, 27.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.5ms
# Speed: 0.8ms preprocess, 27.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 25.5ms
# Speed: 0.7ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 34.6ms
# Speed: 1.7ms preprocess, 34.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.8ms
# Speed: 0.9ms preprocess, 27.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.3ms
# Speed: 0.7ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 25.9ms
# Speed: 0.9ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.4ms
# Speed: 0.9ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.7ms
# Speed: 0.9ms preprocess, 26.7ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 25.7ms
# Speed: 0.9ms preprocess, 25.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 64.2ms
# Speed: 0.8ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 24.1ms
# Speed: 0.7ms preprocess, 24.1ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.7ms
# Speed: 0.6ms preprocess, 27.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.3ms
# Speed: 0.7ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 40.1ms
# Speed: 0.8ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 25.2ms
# Speed: 0.7ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 38.0ms
# Speed: 0.9ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 25.3ms
# Speed: 0.8ms preprocess, 25.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.4ms
# Speed: 0.9ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 31.2ms
# Speed: 12.5ms preprocess, 31.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 25.3ms
# Speed: 0.8ms preprocess, 25.3ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 34.4ms
# Speed: 0.6ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.1ms
# Speed: 0.8ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 24.1ms
# Speed: 0.8ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 alert, 1 pop-up, 26.9ms
# Speed: 0.7ms preprocess, 26.9ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.2ms
# Speed: 0.9ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.8ms
# Speed: 0.7ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.2ms
# Speed: 0.9ms preprocess, 26.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.4ms
# Speed: 0.5ms preprocess, 26.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 26.0ms
# Speed: 0.6ms preprocess, 26.0ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.5ms
# Speed: 0.9ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 38.9ms
# Speed: 0.6ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 27.4ms
# Speed: 0.9ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 34.4ms
# Speed: 0.5ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 25.6ms
# Speed: 0.7ms preprocess, 25.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)
#
# 0: 160x224 2 CTAs, 1 pop-up, 33.5ms
# Speed: 0.7ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 224)

# %%
# Assuming all_areas is a list of tuples where each tuple contains (frame_name, list_of_areas)
sum_data = [(tup[0], sum(tup[1]), len(tup[1]), tup[1]) for tup in all_areas]

# Create DataFrame
Frame_Data_df = pd.DataFrame(sum_data, columns=['Frame', 'Total_Area', 'No_of_Bounding_Boxes', 'Individual_Areas'])

# %%
Frame_Data_df
# Out:
#       Frame     Total_Area  No_of_Bounding_Boxes  \
# 0         1  769530.974652                     5
# 1         2  782786.455085                     5
# 2         3  782881.769880                     5
# 3         4  769508.750484                     5
# 4         5  769386.451053                     5
# ...     ...            ...                   ...
# 2601   2602  314540.224304                     3
# 2602   2603  314636.428282                     3
# 2603   2604  314615.686923                     3
# 2604   2605  314679.112757                     3
# 2605   2606  314566.595166                     3
#
#                                        Individual_Areas
# 0     [419207.82495868206, 20738.51675581187, 116922...
# 1     [419308.08666467667, 20764.720623265952, 11728...
# 2     [419217.05669403076, 20769.6156077981, 117419....
# 3     [419190.43410375714, 20768.261165644974, 11744...
# 4     [20770.498541947454, 419099.34338368475, 11746...
# ...                                                 ...
# 2601  [22140.36712399125, 20439.48525609076, 271960....
# 2602  [22139.785792909563, 20442.683440413326, 27205...
# 2603  [22143.308959431946, 20440.200539585203, 27203...
# 2604  [22139.3238438908, 20435.44445732981, 272104.3...
# 2605  [22143.622525284067, 20438.61377056688, 271984...
#
# [2606 rows x 4 columns]

# %%
def find_duplicate_frames(df):
        start_index = None
        end_index = None
        duplicate_series = []

        for index, row in df.iterrows():
            if index > 0:
                prev_row = df.iloc[index - 1]
                if row['No_of_Bounding_Boxes'] == prev_row['No_of_Bounding_Boxes']:
                    areas_current = row['Individual_Areas']
                    areas_prev = prev_row['Individual_Areas']
                    all_diffs_less_than_100 = all(abs(area_curr - area_prev) < 100 for area_curr, area_prev in zip(areas_current, areas_prev))
                    if all_diffs_less_than_100:
                        if start_index is None:
                            start_index = index - 1
                        end_index = index
                else:
                    if start_index is not None:
                        duplicate_series.append((start_index, end_index))
                        start_index = None
                        end_index = None

        if start_index is not None:
            duplicate_series.append((start_index, end_index))

        if duplicate_series:
            return duplicate_series
        else:
            print("No Duplicated Frames Found")
duplicate_series = find_duplicate_frames(Frame_Data_df)

# %%
Frame_Data_df.shape
# Out:
# (2606, 4)

# %%
duplicate_series
# Out:
# [(4, 6),
#  (7, 8),
#  (16, 21),
#  (24, 29),
#  (42, 43),
#  (75, 76),
#  (218, 220),
#  (245, 247),
#  (272, 276),
#  (329, 330),
#  (358, 361),
#  (373, 374),
#  (392, 393),
#  (443, 444),
#  (460, 497),
#  (502, 573),
#  (574, 575),
#  (585, 589),
#  (590, 591),
#  (595, 596),
#  (606, 706),
#  (711, 716),
#  (718, 734),
#  (738, 750),
#  (752, 770),
#  (782, 868),
#  (872, 879),
#  (882, 883),
#  (886, 887),
#  (982, 983),
#  (1019, 1359),
#  (1360, 1368),
#  (1374, 1382),
#  (1385, 1398),
#  (1401, 1518),
#  (1521, 1522),
#  (1525, 1534),
#  (1536, 1574),
#  (1592, 1613),
#  (1615, 1621),
#  (1624, 1629),
#  (1630, 1644),
#  (1648, 1649),
#  (1656, 1681),
#  (1699, 1710),
#  (1712, 1721),
#  (1726, 1814),
#  (1815, 2110),
#  (2114, 2122),
#  (2128, 2242),
#  (2244, 2250),
#  (2253, 2258),
#  (2262, 2282),
#  (2285, 2286),
#  (2288, 2328),
#  (2331, 2332),
#  (2333, 2442),
#  (2567, 2592),
#  (2594, 2604)]

# %%
def delete_frames_in_duplicate_series(Frame_Data_df, duplicate_series, frame_column='Frame'):
    df_cleaned = Frame_Data_df.copy()
    for start, end in duplicate_series:
        frames_to_delete = list(range(start, end + 1))
        df_cleaned = df_cleaned[~df_cleaned[frame_column].isin(frames_to_delete)]
    return df_cleaned
df_cleaned=delete_frames_in_duplicate_series(Frame_Data_df,duplicate_series)

# %%
def select_frames_with_threshold(duplicate_series, Frame_Data_df, fps, threshold_seconds):
    frames = []
    threshold_frames = int(threshold_seconds * fps)  # Convert threshold to frames

    for start, end in duplicate_series:
        if end - start > threshold_frames:
            random_index = random.randint(start, end)
            random_row = Frame_Data_df.iloc[random_index]
            frames.append(random_row)

    if frames:
        req_frames = pd.DataFrame(frames)
        return req_frames
    else:
        return None
req_frames=select_frames_with_threshold(duplicate_series,Frame_Data_df,fps,threshold_seconds=0.1)

# %%
Frames_to_Retrieve_df=pd.concat([df_cleaned,req_frames])
Frames_to_Retrieve=Frames_to_Retrieve_df["Frame"].astype(int).to_list()

# %%
Frames_to_Retrieve_df
# Out:
#       Frame     Total_Area  No_of_Bounding_Boxes  \
# 0         1  769530.974652                     5
# 1         2  782786.455085                     5
# 2         3  782881.769880                     5
# 8         9  565633.950962                     4
# 9        10  764029.165535                     4
# ...     ...            ...                   ...
# 2270   2271  267432.903361                     3
# 2321   2322  268751.886554                     3
# 2438   2439  268055.356413                     3
# 2581   2582  314657.767139                     3
# 2600   2601  314627.735222                     3
#
#                                        Individual_Areas
# 0     [419207.82495868206, 20738.51675581187, 116922...
# 1     [419308.08666467667, 20764.720623265952, 11728...
# 2     [419217.05669403076, 20769.6156077981, 117419....
# 8     [20796.752253759652, 419369.8316166401, 117723...
# 9     [20783.654214393348, 419406.1090834141, 117482...
# ...                                                 ...
# 2270  [22101.744570415467, 20328.540172219276, 22500...
# 2321  [22083.987729446962, 20313.754096627235, 22635...
# 2438  [22125.254076430574, 20364.533688593656, 22556...
# 2581  [22146.444811904803, 20433.412101387978, 27207...
# 2600  [22134.48081046343, 20434.014004915953, 272059...
#
# [836 rows x 4 columns]

# %%
import cv2
import os

def retrieve_frames(video_path, frames_to_retrieve, output_video_path):
    # Open the video file
    video = cv2.VideoCapture(video_path)
    
    # Check if the video file was successfully opened
    if not video.isOpened():
        print("Error: Unable to open video file")
        return
    
    # Get frames per second
    fps = video.get(cv2.CAP_PROP_FPS)
    
    
    # List to store retrieved frames
    retrieved_frames = []
    
    # Iterate over each frame in the video
    frame_count = 0
    while True:
        ret, frame = video.read()
        if not ret:
            break
        
        frame_count += 1
        
        # Check if the current frame number is in the list of frames to retrieve
        if frame_count in frames_to_retrieve:
            retrieved_frames.append(frame)
            
        # Display progress
        print(f"Processing frame {frame_count} / {int(video.get(cv2.CAP_PROP_FRAME_COUNT))}", end="\r")
    
    # Release the video object
    video.release()
    
    # Write the retrieved frames to a new video file
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out_video = cv2.VideoWriter(output_video_path, fourcc, fps, (retrieved_frames[0].shape[1], retrieved_frames[0].shape[0]))
    for frame in retrieved_frames:
        out_video.write(frame)
    out_video.release()
    print("\nVideo created successfully!")

video_path = "/Users/jatavathpavannaik/Documents/python/Computer_Vision/test_case_03.mov"
output_video_path = "output_video.mp4"

retrieve_frames(video_path, Frames_to_Retrieve, output_video_path)
# Out:
# Processing frame 2606 / 2609
# Video created successfully!
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Automated

# %%
import cv2
from ultralytics import YOLO
import random
import pandas as pd

def process_video(video_path, output_video_path, threshold_seconds=1):
    # Open video capture
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)

    # Create a VideoWriter object to write the output video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out_video = cv2.VideoWriter(output_video_path, fourcc, fps, (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

    # Create DataFrame to store frame data
    all_areas = []
    frame_number = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_number += 1

        # Make predictions
        results = model.predict(frame)

        # Extract bounding box information
        boxes = results[0].boxes.xyxy.tolist()
        classes = results[0].boxes.cls.tolist()
        names = results[0].names
        confidences = results[0].boxes.conf.tolist()

        # Draw bounding boxes on the frame and calculate areas
        areas = []
        for box, cls, conf in zip(boxes, classes, confidences):
            x1, y1, x2, y2 = box
            class_name = names[int(cls)]
            color = (0, 255, 0)  # Green color for bounding box
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
            cv2.putText(frame, f'{class_name} {conf:.2f}', (int(x1), int(y1 - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            # Calculate area
            area = (x2 - x1) * (y2 - y1)
            areas.append(area)

        # Store areas of bounding boxes for this frame
        all_areas.append((frame_number, areas))

        # Write the frame to output video
        out_video.write(frame)

    # Release resources
    cap.release()
    out_video.release()
    cv2.destroyAllWindows()

    # Create DataFrame with frame data
    sum_data = [(tup[0], sum(tup[1]), len(tup[1]), tup[1]) for tup in all_areas]
    Frame_Data_df = pd.DataFrame(sum_data, columns=['Frame', 'Total_Area', 'No_of_Bounding_Boxes', 'Individual_Areas'])

    # Find duplicate frames
    duplicate_series = find_duplicate_frames(Frame_Data_df)

    # Delete frames in duplicate series
    df_cleaned = delete_frames_in_duplicate_series(Frame_Data_df, duplicate_series)

    # Select frames with threshold
    req_frames = select_frames_with_threshold(duplicate_series, Frame_Data_df, fps, threshold_seconds)

    # Concatenate cleaned DataFrame and required frames DataFrame
    Frames_to_Retrieve_df = pd.concat([df_cleaned, req_frames])

    # Retrieve frames
    Frames_to_Retrieve = Frames_to_Retrieve_df["Frame"].astype(int).to_list()
    retrieve_frames(video_path, Frames_to_Retrieve, output_video_path)

def find_duplicate_frames(df):
    start_index = None
    end_index = None
    duplicate_series = []

    for index, row in df.iterrows():
        if index > 0:
            prev_row = df.iloc[index - 1]
            if row['No_of_Bounding_Boxes'] == prev_row['No_of_Bounding_Boxes']:
                areas_current = row['Individual_Areas']
                areas_prev = prev_row['Individual_Areas']
                all_diffs_less_than_100 = all(abs(area_curr - area_prev) < 100 for area_curr, area_prev in zip(areas_current, areas_prev))
                if all_diffs_less_than_100:
                    if start_index is None:
                        start_index = index - 1
                    end_index = index
            else:
                if start_index is not None:
                    duplicate_series.append((start_index, end_index))
                    start_index = None
                    end_index = None

    if start_index is not None:
        duplicate_series.append((start_index, end_index))

    if duplicate_series:
        return duplicate_series
    else:
        print("No Duplicated Frames Found")

def delete_frames_in_duplicate_series(Frame_Data_df, duplicate_series, frame_column='Frame'):
    df_cleaned = Frame_Data_df.copy()
    for start, end in duplicate_series:
        frames_to_delete = list(range(start, end + 1))
        df_cleaned = df_cleaned[~df_cleaned[frame_column].isin(frames_to_delete)]
    return df_cleaned

def select_frames_with_threshold(duplicate_series, Frame_Data_df, fps, threshold_seconds):
    frames = []
    threshold_frames = int(threshold_seconds * fps)  # Convert threshold to frames

    for start, end in duplicate_series:
        if end - start > threshold_frames:
            random_index = random.randint(start, end)
            random_row = Frame_Data_df.iloc[random_index]
            frames.append(random_row)

    if frames:
        req_frames = pd.DataFrame(frames)
        return req_frames
    else:
        return None
    
model = YOLO("/Users/jatavathpavannaik/Documents/python/Computer_Vision/YOLOV8/runs/detect/train_cpu/weights/best.pt")
process_video('/Users/jatavathpavannaik/Documents/python/Computer_Vision/test_case_2.mov', 'output_video.mp4')
